# %% [markdown]
# # d2l香蕉数据集

# %% [markdown]
# ## D2L香蕉物体检测数据集下载

# %%
# %matplotlib inline
from datasets import D2LBananaDatasets

d2l_banana_ds = D2LBananaDatasets("./data")

train_images, train_labels = d2l_banana_ds.load_train_dataset()

# %% [markdown]
# ## 显示图片和查看数据集的基本数据

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20.0, 20.0))
for i in range(5):
    plt.subplot(1, 5, i + 1)
    d2l_banana_ds.draw_image(train_images[i + 200], train_labels[i + 200])
plt.show()
print("train_images[0] shape")
print(train_images[0].shape)
print("train_labels")
print(train_labels)
# Out:
# train_images[0] shape
# (256, 256, 3)
# train_labels
# [[104  20 143  58]
#  [ 68 175 118 223]
#  [163 173 218 239]
#  ...
#  [ 47  54  86 109]
#  [ 43 125  90 166]
#  [191  99 249 152]]
